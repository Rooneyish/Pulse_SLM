# %%
from pathlib import Path
import sys
sys.path.append(str(Path.cwd().parent))
import torch
from src.model import TransformerDecoder

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
data_dir = Path("../data/processed")
data_path = data_dir / "processed_data.pt"
meta_path = data_dir / "pipeline_meta.pt"

# %%
data = torch.load(data_path, map_location=torch.device('cpu'))

# %%
X_train = data['X_train']
X_val = data['X_val']
y_train = data['y_train']
y_val = data['y_val']

X_train.shape, y_train.shape, X_val.shape, y_val.shape
# Out:
# (torch.Size([30270, 64]),
#  torch.Size([30270, 64]),
#  torch.Size([3159, 64]),
#  torch.Size([3159, 64]))

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Instantiate the full modular model
model = TransformerDecoder(
    vocab_size=120377,
    d_model=32,
    num_layers=4,
    num_heads=4,
    seq_len=567,
    head_dim=8,
    hidden_n=128,
).to(device)

# Forward pass test with your batch
batch_x = X_train[:16].to(device)
logits = model(batch_x)

print("Modular model forward pass successful!")
print("Logits shape:", logits.shape)
# Out:
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# Cell In[12], line 16
#      12 ).to(device)
#      13
#      14 # Forward pass test with your batch
#      15 batch_x = X_train[:16].to(device)
# ---> 16 logits = model(batch_x)
#      17
#      18 print("Modular model forward pass successful!")
#      19 print("Logits shape:", logits.shape)
#
# File ~/Documents/Pulse_SLM/.venv/lib/python3.11/site-packages/torch/nn/modules/module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File ~/Documents/Pulse_SLM/.venv/lib/python3.11/site-packages/torch/nn/modules/module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File ~/Documents/Pulse_SLM/src/model.py:63, in TransformerDecoder.forward(self, x)
#      60     x = block(x)
#      62 x = self.final_ln(x)
# ---> 63 logits = x @ self.lm_head
#      65 return logits
#
# OutOfMemoryError: CUDA out of memory. Tried to allocate 472.00 MiB. GPU 0 has a total capacity of 7.53 GiB of which 408.44 MiB is free. Process 5775 has 6.27 GiB memory in use. Including non-PyTorch memory, this process has 800.00 MiB memory in use. Of the allocated memory 657.15 MiB is allocated by PyTorch, and 16.85 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
